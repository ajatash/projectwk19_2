# %%
import pandas as pd
import geopandas as gpd

# %%
shp = "mn_county_boundaries.shp"  
counties = gpd.read_file(shp)
counties.head()
# Out:
#            AREA      PERIMETER  CTYONLY_  CTYONLY_ID  COUN           CTY_NAME  \
# 0  4.608321e+09  388250.145723       2.0         1.0    39  Lake of the Woods
# 1  2.862184e+09  263017.482774       3.0         2.0    35            Kittson
# 2  4.347099e+09  302590.752930       4.0         3.0    68             Roseau
# 3  8.167238e+09  412897.435943       5.0         4.0    36        Koochiching
# 4  4.698732e+09  374207.651291       6.0         5.0    45           Marshall
#
#   CTY_ABBR  CTY_FIPS     Shape_Leng    Shape_Area  \
# 0     LOTW        77  388250.145362  4.608321e+09
# 1     KITT        69  263017.482649  2.862184e+09
# 2     ROSE       135  302590.752705  4.347099e+09
# 3     KOOC        71  412897.435786  8.167238e+09
# 4     MARS        89  374207.651278  4.698732e+09
#
#                                             geometry
# 0  POLYGON ((330081.663 5429937.085, 330973.855 5...
# 1  POLYGON ((250934.678 5433053.183, 250908.729 5...
# 2  POLYGON ((250934.678 5433053.183, 251190.642 5...
# 3  POLYGON ((394785.782 5395220.852, 395221.272 5...
# 4  POLYGON ((249941.883 5382327.086, 251522.947 5...

# %%
counties.to_file("../MN_counties.geojson", driver='GeoJSON')
